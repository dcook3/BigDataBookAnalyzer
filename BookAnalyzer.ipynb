# %%
import re
#with open(r"mobydick.txt") as f:
with open(r"hobbit.txt") as f:
#with open(r"originalTrilogy.txt") as f:
#with open(r"bible.txt") as f:
#with open(r"BigData.txt") as f:
    #Read each line of file and add into list
    lines = f.readlines()

words = []
num_words = 75

#Track line index as well as line
i = 0
for line in lines:
    #Split all words on space (default)
    split_line = line.split()
    
    #Find non-desired characters make new word without them and replace old word with new in same postion
    for i in range(len(split_line)):
        #Remove any occurance of non-alphabetical characters by removing matches using this regular expression
        newword = re.sub(r"[^\w]|\d", "", split_line[i])
        split_line[i] = newword
    
    #Right now, split line is still not in its most simple form. Each line is represented by a list.
    #We would rather have one list with all words, not a 2 dimensional list of lines with words.
    for word in split_line:
        words.append(word.lower())    
    i += 1
    
print(words)
# Out:
# ['chapter', 'i', 'an', 'unexpected', 'party', 'in', 'a', 'hole', 'in', 'the', 'ground', 'there', 'lived', 'a', 'hobbit', 'not', 'a', 'nasty', 'dirty', 'wet', 'hole', 'filled', 'with', 'the', 'ends', 'of', 'worms', 'and', 'an', 'oozy', 'smell', 'nor', 'yet', 'a', 'dry', 'bare', 'sandy', 'hole', 'with', 'nothing', 'in', 'it', 'to', 'sit', 'down', 'on', 'or', 'to', 'eat', 'it', 'was', 'a', 'hobbithole', 'and', 'that', 'means', 'comfort', 'it', 'had', 'a', 'perfectly', 'round', 'door', 'like', 'a', 'porthole', 'painted', 'green', 'with', 'a', 'shiny', 'yellow', 'brass', 'knob', 'in', 'the', 'exact', 'middle', 'the', 'door', 'opened', 'on', 'to', 'a', 'tubeshaped', 'hall', 'like', 'a', 'tunnel', 'a', 'very', 'comfortable', 'tunnel', 'without', 'smoke', 'with', 'panelled', 'walls', 'and', 'floors', 'tiled', 'and', 'carpeted', 'provided', 'with', 'polished', 'chairs', 'and', 'lots', 'and', 'lots', 'of', 'pegs', 'for', 'hats', 'and', 'coats', '', 'the', 'hobbit', 'was', 'fond', 'of', 'visitors', 'the', 'tunnel', 'wound', 'on', 'and', 'on', 'going', 'fairly', 'but', 'not', 'quite', 'straight', 'into', 'the', 'side', 'of', 'the', 'hill', '', 'the', 'hill', 'as', 'all', 'the', 'people', 'for', 'many', 'miles', 'round', 'called', 'it', '', 'and', 'many', 'little', 'round', 'doors', 'opened', 'out', 'of', 'it', 'first', 'on', 'one', 'side', 'and', 'then', 'on', 'another', 'no', 'going', 'upstairs', 'for', 'the', 'hobbit', 'bedrooms', 'bathrooms', 'cellars', 'pantries', 'lots', 'of', 'these', 'wardrobes', 'he', 'had', 'whole', 'rooms', 'devoted', 'to', 'clothes', 'kitchens', 'diningrooms', 'all', 'were', 'on', 'the', 'same', 'floor', 'and', 'indeed', 'on', 'the', 'same', 'passage', 'the', 'best', 'rooms', 'were', 'all', 'on', 'the', 'lefthand', 'side', 'going', 'in', 'for', 'these', 'were', 'the', 'only', 'ones', 'to', 'have', 'windows', 'deepset', 'round', 'windows', 'looking', 'over', 'his', 'garden', 'and', 'meadows', 'beyond', 'sloping', 'down', 'to', 'the', 'river', 'this', 'hobbit', 'was', 'a', 'very', 'welltodo', 'hobbit', 'and', 'his', 'name', 'was', 'baggins', 'the', 'bagginses', 'had', 'lived', 'in', 'the', 'neighbourhood', 'of', 'the', 'hill', 'for', 'time', 'out', 'of', 'mind', 'and', 'people', 'considered', 'them', 'very', 'respectable', 'not', 'only', 'because', 'most', 'of', 'them', 'were', 'rich', 'but', 'also', 'because', 'they', 'never', 'had', 'any', 'adventures', 'or', 'did', 'anything', 'unexpected', 'you', 'could', 'tell', 'what', 'a', 'baggins', 'would', 'say', 'on', 'any', 'question', 'without', 'the', 'bother', 'of', 'asking', 'him', 'this', 'is', 'a', 'story', 'of', 'how', 'a', 'baggins', 'had', 'an', 'adventure', 'found', 'himself', 'doing', 'and', 'saying', 'things', 'altogether', 'unexpected', 'he', 'may', 'have', 'lost', 'the', 'neighbours', 'respect', 'but', 'he', 'gainedwell', 'you', 'will', 'see', 'whether', 'he', 'gained', 'anything', 'in', 'the', 'end', 'the', 'mother', 'of', 'our', 'particular', 'hobbit', '', 'what', 'is', 'a', 'hobbit', 'i', 'suppose', 'hobbits', 'need', 'some', 'description', 'nowadays', 'since', 'they', 'have', 'become', 'rare', 'and', 'shy', 'of', 'the', 'big', 'people', 'as', 'they', 'call', 'us', 'they', 'are', 'or', 'were', 'a', 'little', 'people', 'about', 'half', 'our', 'height', 'and', 'smaller', 'than', 'the', 'bearded', 'dwarves', 'hobbits', 'have', 'no', 'beards', 'there', 'is', 'little', 'or', 'no', 'magic', 'about', 'them', 'except', 'the', 'ordinary', 'everyday', 'sort', 'which', 'helps', 'them', 'to', 'disappear', 'quietly', 'and', 'quickly', 'when', 'large', 'stupid', 'folk', 'like', 'you', 'and', 'me', 'come', 'blundering', 'along', 'making', 'a', 'noise', 'like', 'elephants', 'which', 'they', 'can', 'hear', 'a', 'mile', 'off', 'they', 'are', 'inclined', 'to', 'be', 'at', 'in', 'the', 'stomach', 'they', 'dress', 'in', 'bright', 'colours', 'chiefly', 'green', 'and', 'yellow', 'wear', 'no', 'shoes', 'because', 'their', 'feet', 'grow', 'natural', 'leathery', 'soles', 'and' ...

# %%
#read in words from topWords.txt as top_100
with open(r"topWords.txt") as f:
    top_100 = f.read().split()
print (top_100)
# Out:
# ['the', 'be', 'to', 'of', 'and', 'a', 'in', 'that', 'have', 'i', 'it', 'for', 'not', 'on', 'with', 'he', 'as', 'you', 'do', 'at', 'this', 'but', 'his', 'by', 'from', 'they', 'we', 'say', 'her', 'she', 'or', 'an', 'will', 'my', 'one', 'all', 'would', 'there', 'their', 'what', 'so', 'up', 'out', 'if', 'about', 'who', 'get', 'which', 'go', 'me', 'when', 'make', 'can', 'like', 'time', 'no', 'just', 'him', 'know', 'take', 'people', 'into', 'year', 'your', 'good', 'some', 'could', 'them', 'see', 'other', 'than', 'then', 'now', 'look', 'only', 'come', 'its', 'is', 'over', 'think', 'also', 'back', 'after', 'use', 'two', 'how', 'our', 'work', 'first', 'well', 'way', 'even', 'new', 'want', 'because', 'any', 'these', 'give', 'day', 'most', 'us']

# %%
def value_getter(item):
    return item[1]

#Track words using a word:wordcount dictionary.
words_dict = dict()

for word in words:
    #Determine whether exists to know whether to add a new k/v pair or increment the matching key word
    if word not in words_dict:
        words_dict[word] = 1
    else:
        words_dict[word] = words_dict[word] + 1

#remove '' from words_dict
words_dict.pop('')
for word in top_100:
    if word in words_dict:
        words_dict.pop(word)
#Sort using sorted(), in this case we pull out word and use value_getter to maintain k/v pairs during sort.
words_sorted = dict(sorted(words_dict.items(), key=value_getter, reverse=True))
        
print(words_sorted)
# Out:
# {'was': 1385, 'had': 949, 'were': 696, 'said': 583, 'bilbo': 508, 'down': 315, 'are': 312, 'dwarves': 291, 'very': 256, 'came': 255, 'more': 243, 'before': 235, 'thorin': 235, 'long': 224, 'been': 207, 'did': 196, 'great': 196, 'again': 191, 'still': 183, 'gandalf': 179, 'far': 169, 'little': 166, 'went': 165, 'last': 165, 'where': 157, 'off': 156, 'goblins': 154, 'got': 142, 'soon': 142, 'dark': 142, 'mountain': 140, 'away': 135, 'many': 134, 'too': 129, 'hobbit': 126, 'while': 126, 'thought': 126, 'made': 126, 'dont': 124, 'old': 123, 'though': 117, 'never': 116, 'ever': 116, 'light': 116, 'here': 115, 'through': 114, 'much': 111, 'round': 110, 'am': 110, 'must': 108, 'door': 102, 'under': 102, 'mountains': 102, 'going': 101, 'left': 101, 'baggins': 100, 'end': 100, 'behind': 99, 'river': 98, 'things': 97, 'found': 96, 'himself': 96, 'night': 96, 'right': 95, 'heard': 94, 'water': 93, 'seemed': 93, 'trees': 91, 'without': 90, 'side': 89, 'gollum': 89, 'quite': 87, 'fire': 87, 'has': 86, 'head': 85, 'along': 84, 'eyes': 84, 'forest': 84, 'may': 82, 'once': 82, 'fell': 82, 'began': 81, 'suddenly': 81, 'yet': 80, 'saw': 79, 'dragon': 79, 'nothing': 77, 'king': 77, 'find': 76, 'elves': 76, 'smaug': 76, 'days': 73, 'another': 72, 'men': 71, 'course': 70, 'gold': 70, 'looked': 68, 'mr': 68, 'shall': 68, 'took': 67, 'ring': 67, 'till': 66, 'others': 66, 'path': 66, 'balin': 65, 'something': 64, 'upon': 64, 'above': 63, 'enough': 62, 'own': 62, 'should': 62, 'such': 62, 'help': 62, 'until': 60, 'sat': 60, 'seen': 60, 'put': 60, 'stone': 60, 'turned': 59, 'coming': 59, 'towards': 59, 'lost': 58, 'wizard': 58, 'valley': 58, 'feet': 57, 'place': 57, 'let': 57, 'nor': 56, 'asked': 56, 'bombur': 56, 'bard': 56, 'already': 55, 'beorn': 55, 'those': 54, 'inside': 54, 'knew': 54, 'brought': 54, 'near': 54, 'ponies': 54, 'morning': 53, 'sun': 53, 'used': 53, 'hand': 53, 'gone': 53, 'lake': 53, 'tell': 52, 'really': 52, 'cried': 52, 'black': 51, 'cold': 51, 'lay': 51, 'being': 50, 'among': 50, 'gate': 50, 'air': 49, 'might': 49, 'friends':
# %%
#get the frequency of the top words in the english language using datamuse API
import requests
import json

top_words_frequency = dict()
for word in top_words:
    word_frequency_request = requests.get("https://api.datamuse.com/words?sp=" + word[0] + "&md=f")
    word_frequency_json = word_frequency_request.json()
    try:
        word_frequency = word_frequency_json[0]['tags'][0][2:]
    #if try fails, set frequency to minimum decimal value
    except:
        word_frequency = 0.001
    #f is occurances per million, so divide by 1000000 to get frequency
    word_frequency = float(word_frequency) / 1000000
    top_words_frequency[word[0]] = word_frequency
print(top_words_frequency)
# Out:
# {'was': 0.002824169367, 'had': 0.000693891276, 'were': 0.0009467195809999999, 'said': 0.000671754948, 'bilbo': 1.9597e-07, 'down': 0.000188994664, 'are': 0.001982889722, 'dwarves': 2.01563e-07, 'very': 0.000577371772, 'came': 0.000253203835, 'more': 0.001291879626, 'before': 0.000336211949, 'thorin': 3.8330999999999994e-08, 'long': 0.00038198848099999996, 'been': 0.000428888624, 'did': 0.000178524971, 'great': 0.00034815727, 'again': 0.00028433378499999996, 'still': 0.000343352114, 'gandalf': 1.22494e-07, 'far': 0.000211598915, 'little': 0.000343154023, 'went': 0.000203934388, 'last': 0.000233819604, 'where': 0.000397281742, 'off': 9.8391485e-05, 'goblins': 3.08971e-07, 'got': 0.00015713220200000002, 'soon': 0.000121971241, 'dark': 6.8871627e-05, 'mountain': 3.5046053e-05, 'away': 0.00019175632300000002, 'many': 0.0006247913959999999, 'too': 0.00034227760000000003, 'hobbit': 1.17773e-07, 'while': 5.0449541000000004e-05, 'thought': 0.000249773804, 'made': 0.000543336821, 'dont': 1.2809219999999999e-06, 'old': 0.000298550312, 'though': 0.00011878977500000001, 'never': 1.470637e-05, 'ever': 0.000152490996, 'light': 0.000173467557, 'here': 0.00038715637, 'through': 0.000528946114, 'much': 0.000473014857, 'round': 6.2224368e-05, 'am': 0.000157661961, 'must': 8.016287999999999e-06, 'door': 9.9584058e-05, 'under': 0.000392221462, 'mountains': 2.7442945e-05, 'going': 0.000198590107, 'left': 0.000262676846, 'baggins': 2.4216e-08, 'end': 0.00025825168, 'behind': 0.000106822256, 'river': 8.851187400000001e-05, 'things': 0.000210884086, 'found': 0.00034486433699999996, 'himself': 0.00021581897, 'night': 0.00014576726400000002, 'right': 0.000336057616, 'heard': 0.000100397462, 'water': 0.000278163521, 'seemed': 0.000116273224, 'trees': 4.7841176e-05, 'without': 0.000343014524, 'side': 0.000188963448, 'gollum': 5.2522e-08, 'quite': 0.000147135294, 'fire': 8.588774499999999e-05, 'has': 0.000412414222, 'head': 0.000188298221}

# %%
percent_gap = dict()
for word in top_words:
    gap = in_text_frequency[word[0]]/top_words_frequency[word[0]]
    #round to 2 decimal places
    gap = round(gap, 2)
    percent_gap[word[0]] = gap
percent_gap_sorted = dict(sorted(percent_gap.items(), key=value_getter, reverse=True))
print(percent_gap_sorted)
# Out:
# {'thorin': 64292.54, 'baggins': 43305.24, 'bilbo': 27184.23, 'gollum': 17770.17, 'gandalf': 15324.32, 'dwarves': 15139.97, 'hobbit': 11219.35, 'goblins': 5226.92, 'dont': 1015.18, 'must': 141.28, 'never': 82.72, 'mountain': 41.89, 'mountains': 38.98, 'while': 26.19, 'dark': 21.62, 'trees': 19.95, 'round': 18.54, 'down': 17.48, 'off': 16.63, 'had': 14.34, 'soon': 12.21, 'river': 11.61, 'did': 11.51, 'door': 10.74, 'fire': 10.62, 'came': 10.56, 'though': 10.33, 'heard': 9.82, 'behind': 9.72, 'got': 9.48, 'said': 9.1, 'went': 8.48, 'seemed': 8.39, 'far': 8.38, 'ever': 7.98, 'were': 7.71, 'last': 7.4, 'away': 7.38, 'before': 7.33, 'am': 7.32, 'again': 7.04, 'light': 7.01, 'night': 6.91, 'quite': 6.2, 'long': 6.15, 'great': 5.9, 'still': 5.59, 'going': 5.33, 'thought': 5.29, 'was': 5.14, 'little': 5.07, 'been': 5.06, 'side': 4.94, 'things': 4.82, 'head': 4.73, 'himself': 4.66, 'very': 4.65, 'old': 4.32, 'where': 4.14, 'end': 4.06, 'left': 4.03, 'too': 3.95, 'water': 3.51, 'here': 3.11, 'right': 2.96, 'found': 2.92, 'without': 2.75, 'under': 2.73, 'much': 2.46, 'made': 2.43, 'through': 2.26, 'many': 2.25, 'has': 2.19, 'more': 1.97, 'are': 1.65}

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

#create a grouped bar chart for the top 10 and bottom 10 words showing their frequency in the text and in the english language
top_5_words = list(percent_gap_sorted)[:10]
bottom_5_words = list(percent_gap_sorted)[-10:]
words_frequency = dict()
for word in top_5_words:
    words_frequency[word] = [in_text_frequency[word], top_words_frequency[word]]
for word in bottom_5_words:
    words_frequency[word] = [in_text_frequency[word], top_words_frequency[word]]


#create the clustered bar chart, each word will have 2 bars
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
ax.set_title('Frequency of Top and Bottom 10 Words in Text and English Language')
ax.set_xlabel('Words')
ax.set_ylabel('Frequency')
ax.set_xticks(np.arange(len(words_frequency)))
ax.set_xticklabels(words_frequency.keys())
#make x labels smaller
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
    tick.label.set_fontweight('bold')

text_container = ax.bar(np.arange(len(words_frequency)), [x[0] for x in words_frequency.values()], width=0.4, color='g', align='center')
eng_container = ax.bar(np.arange(len(words_frequency)) + 0.4, [x[1] for x in words_frequency.values()], width=0.4, color='r', align='center')
    
ax.legend(['Text', 'English Language'])
plt.show()
# Out:
# C:\Users\jsher\AppData\Local\Temp\ipykernel_56484\1639647297.py:25: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)
# C:\Users\jsher\AppData\Local\Temp\ipykernel_56484\1639647297.py:26: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontweight('bold')

# %%
#create a pie chart of the top 10 words from top_words
top_10_words = list(top_words)[:20]
top_10_words = dict(top_10_words)
plt.figure(figsize=(15,15))
plt.title('Top 20 Words by Count')
plt.rcParams.update({'font.size': 18})
plt.pie(top_10_words.values(), labels=top_10_words.keys(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x184fb201cd0>,
#   <matplotlib.patches.Wedge at 0x184fb201be0>,
#   <matplotlib.patches.Wedge at 0x184fb2109a0>,
#   <matplotlib.patches.Wedge at 0x184fb228070>,
#   <matplotlib.patches.Wedge at 0x184fb228700>,
#   <matplotlib.patches.Wedge at 0x184fb228dc0>,
#   <matplotlib.patches.Wedge at 0x184fb236490>,
#   <matplotlib.patches.Wedge at 0x184fb236b20>,
#   <matplotlib.patches.Wedge at 0x184fb2451f0>,
#   <matplotlib.patches.Wedge at 0x184fb245880>,
#   <matplotlib.patches.Wedge at 0x184fb201ca0>,
#   <matplotlib.patches.Wedge at 0x184fb2535e0>,
#   <matplotlib.patches.Wedge at 0x184fb253c70>,
#   <matplotlib.patches.Wedge at 0x184fb25f340>,
#   <matplotlib.patches.Wedge at 0x184faf08250>,
#   <matplotlib.patches.Wedge at 0x184fb25fa30>,
#   <matplotlib.patches.Wedge at 0x184fb269100>,
#   <matplotlib.patches.Wedge at 0x184fb269790>,
#   <matplotlib.patches.Wedge at 0x184fb269e20>,
#   <matplotlib.patches.Wedge at 0x184fb26f4f0>],
#  [Text(0.9263337660222384, 0.5932164477887115, 'was'),
#   Text(0.04545153588384244, 1.099060579716059, 'had'),
#   Text(-0.6526604214882948, 0.8854571554980634, 'were'),
#   Text(-1.0090029323285947, 0.43807885426290294, 'said'),
#   Text(-1.0991605772004713, -0.042965399198970924, 'bilbo'),
#   Text(-1.0225341727361643, -0.4054921276507944, 'down'),
#   Text(-0.8853229393157364, -0.6528424719037089, 'are'),
#   Text(-0.6979965404308192, -0.8501769401404674, 'dwarves'),
#   Text(-0.49076476538434805, -0.9844541355783143, 'very'),
#   Text(-0.2746016275696739, -1.065173200064706, 'came'),
#   Text(-0.052230600629991165, -1.0987592840826559, 'more'),
#   Text(0.16338194767006292, -1.0877988505121419, 'before'),
#   Text(0.36929404695203155, -1.0361572790294873, 'thorin'),
#   Text(0.5571668024000577, -0.9484540865552192, 'long'),
#   Text(0.7156733590347165, -0.8353512094729771, 'been'),
#   Text(0.8436818621119387, -0.7058334899559042, 'did'),
#   Text(0.9460392471882428, -0.5612572875068109, 'great'),
#   Text(1.0230336486238731, -0.40423032269156356, 'again'),
#   Text(1.0728861098629252, -0.24272493745637116, 'still'),
#   Text(1.0970207991859515, -0.08090343721633039, 'gandalf')],
#  [Text(0.5052729632848573, 0.3235726078847517, '18.1%'),
#   Text(0.024791746845732234, 0.5994875889360322, '12.4%'),
#   Text(-0.35599659353906987, 0.4829766302716708, '9.1%'),
#   Text(-0.550365235815597, 0.23895210232521977, '7.6%'),
#   Text(-0.5995421330184388, -0.023435672290347775, '6.7%'),
#   Text(-0.5577459124015441, -0.22117752417316058, '4.1%'),
#   Text(-0.482903421444947, -0.35609589376565937, '4.1%'),
#   Text(-0.3807253856895377, -0.4637328764402549, '3.8%'),
#   Text(-0.2676898720278262, -0.5369749830427168, '3.4%'),
#   Text(-0.14978270594709484, -0.5810035636716577, '3.3%'),
#   Text(-0.028489418525449724, -0.5993232458632668, '3.2%'),
#   Text(0.0891174260018525, -0.5933448275520773, '3.1%'),
#   Text(0.20143311651928994, -0.5651766976524476, '3.1%'),
#   Text(0.303909164945486, -0.5173385926664832, '2.9%'),
#   Text(0.39036728674620896, -0.45564611425798746, '2.7%'),
#   Text(0.460190106606512, -0.3850000854304932, '2.6%'),
#   Text(0.5160214075572233, -0.3061403386400786, '2.6%'),
#   Text(0.5580183537948399, -0.220489266922671, '2.5%'),
#   Text(0.5852106053797773, -0.1323954204307479, '2.4%'),
#   Text(0.5983749813741552, -0.044129147572543846, '2.3%')])

# %%
#create a pie chart of the top 5 words from percent_gap_sorted using logarithmic scale to account for small numbers
top_5_pct_gap = list(percent_gap_sorted.items())[:20]
top_5_pct_gap = dict(top_5_pct_gap)
#convert to log scale
for word in top_5_pct_gap:
    top_5_pct_gap[word] = math.log(top_5_pct_gap[word])
plt.figure(figsize=(15,15))
plt.title('Top 20 Words by Frequency Analysis')
plt.rcParams.update({'font.size': 18})
plt.pie(top_5_pct_gap.values(), labels=top_5_pct_gap.keys(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x184fb2c17f0>,
#   <matplotlib.patches.Wedge at 0x184fb2c1700>,
#   <matplotlib.patches.Wedge at 0x184fb2cf400>,
#   <matplotlib.patches.Wedge at 0x184fb2cfa90>,
#   <matplotlib.patches.Wedge at 0x184fb2de160>,
#   <matplotlib.patches.Wedge at 0x184fb2de7f0>,
#   <matplotlib.patches.Wedge at 0x184fb2dee20>,
#   <matplotlib.patches.Wedge at 0x184fb2ed4f0>,
#   <matplotlib.patches.Wedge at 0x184fb2edbb0>,
#   <matplotlib.patches.Wedge at 0x184fb2fa280>,
#   <matplotlib.patches.Wedge at 0x184fb2c17c0>,
#   <matplotlib.patches.Wedge at 0x184fb2faf70>,
#   <matplotlib.patches.Wedge at 0x184fb308640>,
#   <matplotlib.patches.Wedge at 0x184fb308cd0>,
#   <matplotlib.patches.Wedge at 0x184fb3153a0>,
#   <matplotlib.patches.Wedge at 0x184fb315a30>,
#   <matplotlib.patches.Wedge at 0x184fb325100>,
#   <matplotlib.patches.Wedge at 0x184fb325790>,
#   <matplotlib.patches.Wedge at 0x184fb325e20>,
#   <matplotlib.patches.Wedge at 0x184fb3314f0>],
#  [Text(1.0564310865053284, 0.30651812257217625, 'thorin'),
#   Text(0.736586492236657, 0.8169702194416254, 'baggins'),
#   Text(0.21956708014708334, 1.07786376565672, 'bilbo'),
#   Text(-0.33458982396848735, 1.0478786426379425, 'gollum'),
#   Text(-0.7925135505383529, 0.7628383001744824, 'gandalf'),
#   Text(-1.0586673550425687, 0.2987029148956736, 'dwarves'),
#   Text(-1.0762073575718365, -0.2275471896294167, 'hobbit'),
#   Text(-0.8658762264102047, -0.6784234374913829, 'goblins'),
#   Text(-0.5381783471118092, -0.9593560687773862, 'dont'),
#   Text(-0.2275586134862191, -1.0762049421128996, 'must'),
#   Text(0.033573356968622035, -1.0994875304894811, 'never'),
#   Text(0.2597839073265325, -1.068883680057919, 'mountain'),
#   Text(0.45567786876588634, -1.0011781459445566, 'mountains'),
#   Text(0.6245916462072773, -0.9054751655832884, 'while'),
#   Text(0.7622121952792269, -0.7931157351658218, 'dark'),
#   Text(0.875346562975294, -0.6661594363869207, 'trees'),
#   Text(0.9655026339154197, -0.5270717824949342, 'round'),
#   Text(1.0324630811343003, -0.37949965229848026, 'down'),
#   Text(1.0763909954439201, -0.226676917499879, 'off'),
#   Text(1.0974633106981095, -0.07466111217725625, 'had')],
#  [Text(0.5762351380938154, 0.167191703221187, '9.0%'),
#   Text(0.40177445031090375, 0.44562011969543197, '8.7%'),
#   Text(0.11976386189840907, 0.5879256903582109, '8.3%'),
#   Text(-0.1825035403464476, 0.5715701687116049, '7.9%'),
#   Text(-0.43228011847546516, 0.4160936182769904, '7.8%'),
#   Text(-0.5774549209323101, 0.1629288626703674, '7.8%'),
#   Text(-0.5870221950391834, -0.12411664888877273, '7.6%'),
#   Text(-0.4722961234964752, -0.3700491477225724, '7.0%'),
#   Text(-0.29355182569735044, -0.5232851284240289, '5.6%'),
#   Text(-0.12412288008339223, -0.5870208775161271, '4.0%'),
#   Text(0.018312740164702926, -0.5997204711760805, '3.6%'),
#   Text(0.14170031308719955, -0.5830274618497739, '3.0%'),
#   Text(0.2485515647813925, -0.5460971705152127, '3.0%'),
#   Text(0.34068635247669665, -0.4938955448636118, '2.7%'),
#   Text(0.4157521065159419, -0.4326085828177209, '2.5%'),
#   Text(0.47746176162288756, -0.3633596925746839, '2.4%'),
#   Text(0.5266378003175016, -0.2874936995426914, '2.4%'),
#   Text(0.5631616806187092, -0.20699981034462558, '2.3%'),
#   Text(0.5871223611512291, -0.123641954999934, '2.3%'),
#   Text(0.5986163512898779, -0.04072424300577613, '2.2%')])

# %%
#generate a word cloud of the top 20 words by frequency
try: 
    from wordcloud import WordCloud
except:
    # !pip install wordcloud
    from wordcloud import WordCloud

top_20_words = list(percent_gap_sorted.items())[:20]
top_20_words = dict(top_20_words)
#convert to log scale
for word in top_20_words:
    top_20_words[word] = math.log(top_20_words[word])

wordcloud = WordCloud(width=480, height=480, margin=0, colormap='Greens').generate_from_frequencies(top_20_words)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
#generate a word cloud of the bottom 20 words by frequency, this one should be warmer colors, small values should be larger
bottom_20_words = list(percent_gap_sorted.items())[-20:]
bottom_20_words = dict(bottom_20_words)

#convert to log scale
for word in bottom_20_words:
    bottom_20_words[word] = math.log(bottom_20_words[word])

wordcloud = WordCloud(width=480, height=480, margin=0, colormap='Reds').generate_from_frequencies(bottom_20_words)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
