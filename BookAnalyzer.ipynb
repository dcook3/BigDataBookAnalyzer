# %%
import re
#with open(r"mobydick.txt") as f:
#with open(r"hobbit.txt") as f:
#with open(r"originalTrilogy.txt") as f:
#with open(r"bible.txt") as f:
with open(r"BigData.txt") as f:
    #Read each line of file and add into list
    lines = f.readlines()

words = []

#Track line index as well as line
i = 0
for line in lines:
    #Split all words on space (default)
    split_line = line.split()
    
    #Find non-desired characters make new word without them and replace old word with new in same postion
    for i in range(len(split_line)):
        #Remove any occurance of non-alphabetical characters by removing matches using this regular expression
        newword = re.sub(r"[^\w]|\d", "", split_line[i])
        split_line[i] = newword
    
    #Right now, split line is still not in its most simple form. Each line is represented by a list.
    #We would rather have one list with all words, not a 2 dimensional list of lines with words.
    for word in split_line:
        words.append(word.lower())    
    i += 1
    
print(words)
# Out:
# ['chapter', 'i', 'introduction', 'the', 'top', '', 'indemand', 'jobs', 'projected', 'for', '', 'did', 'not', 'exist', 'in', '', 'thus', 'the', 'new', 'mission', 'of', 'schools', 'is', 'to', 'prepare', 'students', 'to', 'work', 'at', 'jobs', 'that', 'do', 'not', 'yet', 'exist', 'creating', 'ideas', 'and', 'solutions', 'for', 'products', 'and', 'problems', 'that', 'have', 'not', 'yet', 'been', 'identified', 'using', 'technologies', 'that', 'have', 'not', 'yet', 'been', 'invented', 'linda', 'darlinghammond', 'this', 'research', 'study', 'was', 'designed', 'to', 'identify', 'how', 'the', 'game', 'development', 'department', 'at', 'oceanfront', 'college', 'went', 'about', 'making', 'continuous', 'changes', 'to', 'their', 'gdsp', 'curriculum', 'despite', 'some', 'of', 'the', 'millenniaold', 'constraints', 'that', 'colleges', 'and', 'universities', 'abide', 'by', 'when', 'developing', 'curriculum', 'the', 'process', 'used', 'by', 'ocs', 'faculty', 'and', 'administrators', 'to', 'dynamically', 'update', 'their', 'curriculum', 'could', 'serve', 'to', 'inform', 'others', 'who', 'are', 'concerned', 'about', 'alleviating', 'a', 'widening', 'skills', 'gap', 'a', 'skills', 'gap', 'is', 'a', 'point', 'in', 'an', 'organizations', 'life', 'cycle', 'where', 'it', 'can', 'no', 'longer', 'grow', 'and', 'remain', 'competitive', 'because', 'its', 'employees', 'lack', 'the', 'skills', 'they', 'need', 'to', 'achieve', 'its', 'goals', 'american', 'society', 'for', 'training', 'and', 'development', '', 'beach', '', 'cappelli', '', 'there', 'are', 'several', 'causes', 'for', 'the', 'skills', 'gap', 'included', 'are', 'changes', 'in', 'workforce', 'demographics', 'beard', 'schwieger', '', 'surendran', '', 'changes', 'in', 'technology', 'and', 'evolving', 'business', 'models', 'cruea', '', 'greene', '', 'shift', 'to', 'a', 'service', 'economy', 'requiring', 'knowledge', 'workers', 'american', 'society', 'for', 'training', 'and', 'development', '', 'beach', '', 'drucker', '', 'elkeles', '', 'phillips', '', 'nakamori', '', 'shifting', 'conditions', 'in', 'the', 'environment', 'and', 'in', 'the', 'changing', 'expectations', 'of', 'constituents', 'alvior', '', 'benamati', 'ozdemir', '', 'smith', '', 'mann', '', 'shao', '', 'david', '', 'as', 'well', 'as', 'underprepared', 'students', 'arum', '', 'ruska', '', 'bateman', '', 'beach', '', 'a', 'college', 'or', 'university', 'can', 'help', 'bridge', 'the', 'skills', 'gap', 'beach', '', 'galagan', 'a', 'galagan', 'b', 'in', 'order', 'to', 'gain', 'insight', 'into', 'the', 'curriculum', 'change', 'process', 'at', 'oceanfront', 'college', 'answers', 'to', 'critical', 'questions', 'were', 'sought', 'for', 'example', 'what', 'prompted', 'the', 'changes', 'to', 'the', 'curriculum', 'how', 'was', 'the', 'need', 'for', 'change', 'first', 'detected', 'what', 'activities', 'were', 'followed', 'after', 'determining', 'that', 'a', 'change', 'was', 'necessary', 'who', 'were', 'the', 'stakeholders', 'whose', 'inputs', 'were', 'heard', 'by', 'the', 'decision', 'makers', 'how', 'were', 'the', 'decisions', 'to', 'add', 'and', 'discard', 'courses', 'made', 'who', 'approved', 'the', 'changes', 'who', 'else', 'should', 'have', 'been', 'consulted', 'what', 'tradeoffs', 'were', 'weighed', 'what', 'benefits', 'risks', 'and', 'safeguards', 'were', 'considered', 'how', 'long', 'did', 'it', 'take', 'for', 'the', 'change', 'process', 'to', 'transpire', 'from', 'identification', 'to', 'implementation', 'what', 'changes', 'were', 'made', 'to', 'infrastructure', 'curricular', 'framework', 'instructional', 'strategies', 'processes', 'as', 'well', 'as', 'policies', 'how', 'were', 'the', 'change', 'results', 'assessed', 'due', 'to', 'the', 'pragmatic', 'nature', 'of', 'these', 'questions', 'a', 'case', 'study', 'was', 'conducted', 'at', 'oc', 'to', 'examine', 'what', 'occurred', 'statement', 'of', 'the', 'problem', 'problem', 'of', 'practice', 'curriculum', 'leaders', 'including', 'professors', 'and', 'administrators', 'who', 'were', 'responsibl ...

# %%
#read in words from topWords.txt as top_100
with open(r"topWords.txt") as f:
    top_100 = f.read().split()
print (top_100)
# Out:
# ['the', 'be', 'to', 'of', 'and', 'a', 'in', 'that', 'have', 'i', 'it', 'for', 'not', 'on', 'with', 'he', 'as', 'you', 'do', 'at', 'this', 'but', 'his', 'by', 'from', 'they', 'we', 'say', 'her', 'she', 'or', 'an', 'will', 'my', 'one', 'all', 'would', 'there', 'their', 'what', 'so', 'up', 'out', 'if', 'about', 'who', 'get', 'which', 'go', 'me', 'when', 'make', 'can', 'like', 'time', 'no', 'just', 'him', 'know', 'take', 'people', 'into', 'year', 'your', 'good', 'some', 'could', 'them', 'see', 'other', 'than', 'then', 'now', 'look', 'only', 'come', 'its', 'is', 'over', 'think', 'also', 'back', 'after', 'use', 'two', 'how', 'our', 'work', 'first', 'well', 'way', 'even', 'new', 'want', 'because', 'any', 'these', 'give', 'day', 'most', 'us']

# %%
def value_getter(item):
    return item[1]

#Track words using a word:wordcount dictionary.
words_dict = dict()

for word in words:
    #Determine whether exists to know whether to add a new k/v pair or increment the matching key word
    if word not in words_dict:
        words_dict[word] = 1
    else:
        words_dict[word] = words_dict[word] + 1

#remove '' from words_dict
words_dict.pop('')
for word in top_100:
    if word in words_dict:
        words_dict.pop(word)
#Sort using sorted(), in this case we pull out word and use value_getter to maintain k/v pairs during sort.
words_sorted = dict(sorted(words_dict.items(), key=value_getter, reverse=True))
        
print(words_sorted)
# Out:
# {'are': 390, 'curriculum': 372, 'industry': 306, 'skills': 270, 'college': 263, 'was': 245, 'students': 241, 'change': 219, 'faculty': 211, 'were': 205, 'changes': 157, 'process': 145, 'program': 133, 'research': 132, 'through': 132, 'knowledge': 127, 'professors': 109, 'video': 109, 'department': 108, 'et': 108, 'al': 108, 'data': 107, 'development': 100, 'colleges': 99, 'learning': 93, 'gap': 91, 'oceanfront': 90, 'has': 89, 'members': 87, 'gaming': 83, 'study': 82, 'game': 81, 'help': 81, 'need': 79, 'administrators': 78, 'should': 78, 'ideas': 77, 'order': 77, 'participants': 77, 'information': 74, 'course': 73, 'idea': 71, 'education': 67, 'more': 67, 'including': 64, 'example': 60, 'may': 60, 'donald': 60, 'several': 58, 'organizational': 58, 'within': 58, 'needs': 56, 'class': 56, 'between': 54, 'student': 54, 'programs': 54, 'where': 53, 'organization': 52, 'committee': 51, 'oc': 50, 'needed': 50, 'mark': 50, 'used': 49, 'leaders': 48, 'internal': 48, 'x': 48, 'part': 47, 'quarter': 47, 'made': 46, 'external': 46, 'framework': 45, 'technical': 45, 'different': 44, 'years': 44, 'graduates': 44, 'classes': 44, 'wilhelm': 44, 'interview': 43, 'each': 43, 'institutions': 42, 'individual': 42, 'member': 42, 'innovative': 41, 'degree': 41, 'level': 41, 'been': 40, 'literature': 40, 'experiences': 40, 'both': 40, 'review': 40, 'alan': 40, 'dennis': 40, 'courses': 38, 'sense': 38, 'educators': 38, 'steve': 38, 'innovation': 37, 'mission': 36, 'relevant': 36, 'curricula': 36, 'mcgee': 36, 'higher': 36, 'technology': 35, 'problem': 35, 'dynamic': 35, 'involved': 35, 'theoretical': 35, 'skill': 35, 'those': 35, 'making': 34, 'critical': 34, 'seelos': 34, 'occi': 34, 'approach': 34, 'while': 34, 'looking': 34, 'content': 34, 'b': 33, 'institution': 33, 'findings': 33, 'educational': 33, 'based': 33, 'meadows': 33, 'employers': 33, 'provost': 33, 'processes': 32, 'things': 32, 'feedback': 32, 'too': 32, 'teaching': 32, 'ada': 32, 'questions': 31, 'current': 31, 'experience': 31, 'experts': 31, 'anders': 31, 'continuous': 30, 'training': 30, 'design': 30, 'field': 30, 'senge': 30, 'academic': 30, 'team': 30, 'advisory': 30, 'professor': 30, 'universities': 29, 'organizations': 29, 'many': 29, 'right': 29, 'ways': 29, 'context': 29, 'according': 29, 'group': 29, 'must': 29, 'document': 29, 'beach': 28, 'maintenance': 28, 'during': 28, 'theory': 28, 'shared': 28, 'very': 28, 'chair': 28, 'trends': 28, 'elkeles': 27, 'phillips': 27, 'regarding': 27, 'job': 27, 'together': 27, 'identified': 26, 'business': 26, 'include': 26, 'future': 26, 'asked': 26, 'same': 26, 'able': 26, 'peers': 26, 'once': 26, 'chapter': 25, 'using': 25, 'american': 25, 'professionals': 25, 'mair': 25, 'academia': 25, 'three': 25, 'success': 25, 'thinking': 25, 'yes': 25, 'creation': 24, 'bachelors': 24, 'created': 24, 'crossan': 24, 'open': 24, 'support': 24, 'taught': 24, 'had': 24, 'conversation': 24, 'results': 23, 'question': 23, 'continuously': 23, 'analysis': 23, 'investigator': 23, 'learned': 23, 'something': 23, 'classroom': 23, 'culture': 23, 'another': 23, 'themes': 23, 'going': 23, 'curricular': 22, 'case': 22, 'among': 22, 'understanding': 22, 'creswell': 22, 'systems': 22, 'following': 22, 'before': 22, 'previous': 22, 'instructors': 22, 'does': 22, 'growth': 22, 'provided': 22, 'sources': 22, 'observed': 22, 'society': 21, 'included': 21, 'sought': 21, 'conducted': 21, 'understand': 21, 'christensen': 21, 'develop': 21, 'learn': 21, 'best': 21, 'governance': 21, 'explained': 21, 'mapping': 21, 'system': 21, 'programming': 21, 'appendix': 21, 'senior': 21, 'indicated': 21, 'gain': 20, 'whether': 20, 'reviewed': 20, 'events': 20, 'ability': 20, 'doing': 20, 'next': 20, 'specific': 20, 'major': 20, 'much': 20, 'implemented': 20, 'number': 20, 'associate': 20, 'working': 20, 'theme': 20, 'table': 20, 'jobs': 19, 'others': 19, 'goals': 19, 'workers': 19, 'merriam': 19, 'every': 19, 'researcher': 19, 'therefore': 19, 'hisher': 19, 'participant': 19, 'prep ...

# %%
print(len(words_dict))
# Out:
# 4437

# %%
#top words from words_sorted
top_words = list(words_sorted.items())[:75]
print(top_words)
# Out:
# [('are', 390), ('curriculum', 372), ('industry', 306), ('skills', 270), ('college', 263), ('was', 245), ('students', 241), ('change', 219), ('faculty', 211), ('were', 205), ('changes', 157), ('process', 145), ('program', 133), ('research', 132), ('through', 132), ('knowledge', 127), ('professors', 109), ('video', 109), ('department', 108), ('et', 108), ('al', 108), ('data', 107), ('development', 100), ('colleges', 99), ('learning', 93), ('gap', 91), ('oceanfront', 90), ('has', 89), ('members', 87), ('gaming', 83), ('study', 82), ('game', 81), ('help', 81), ('need', 79), ('administrators', 78), ('should', 78), ('ideas', 77), ('order', 77), ('participants', 77), ('information', 74), ('course', 73), ('idea', 71), ('education', 67), ('more', 67), ('including', 64), ('example', 60), ('may', 60), ('donald', 60), ('several', 58), ('organizational', 58), ('within', 58), ('needs', 56), ('class', 56), ('between', 54), ('student', 54), ('programs', 54), ('where', 53), ('organization', 52), ('committee', 51), ('oc', 50), ('needed', 50), ('mark', 50), ('used', 49), ('leaders', 48), ('internal', 48), ('x', 48), ('part', 47), ('quarter', 47), ('made', 46), ('external', 46), ('framework', 45), ('technical', 45), ('different', 44), ('years', 44), ('graduates', 44)]

# %%
#calculate the percentage of the original document that each word makes up
num_words = len(words)
in_text_frequency = dict()
for word in top_words:
    word_count = word[1]
    percentage = word_count / num_words
    in_text_frequency[word[0]] = percentage
print(in_text_frequency)
# Out:
# {'are': 0.008557698637351063, 'curriculum': 0.008162727931011783, 'industry': 0.006714502007767758, 'skills': 0.005924560595089197, 'college': 0.005770960875957255, 'was': 0.005375990169617976, 'students': 0.00528821890154258, 'change': 0.004805476927127904, 'faculty': 0.004629934390977114, 'were': 0.004498277488864021, 'changes': 0.003445022271959274, 'process': 0.0031817084677330876, 'program': 0.002918394663506901, 'research': 0.002896451846488052, 'through': 0.002896451846488052, 'knowledge': 0.002786737761393808, 'professors': 0.0023917670550545277, 'video': 0.0023917670550545277, 'department': 0.002369824238035679, 'et': 0.002369824238035679, 'al': 0.002369824238035679, 'data': 0.0023478814210168304, 'development': 0.002194281701884888, 'colleges': 0.002172338884866039, 'learning': 0.0020406819827529458, 'gap': 0.001996796348715248, 'oceanfront': 0.001974853531696399, 'has': 0.0019529107146775504, 'members': 0.0019090250806398526, 'gaming': 0.001821253812564457, 'study': 0.0017993109955456081, 'game': 0.0017773681785267592, 'help': 0.0017773681785267592, 'need': 0.0017334825444890614, 'administrators': 0.0017115397274702125, 'should': 0.0017115397274702125, 'ideas': 0.0016895969104513638, 'order': 0.0016895969104513638, 'participants': 0.0016895969104513638, 'information': 0.0016237684593948172, 'course': 0.0016018256423759683, 'idea': 0.0015579400083382705, 'education': 0.0014701687402628749, 'more': 0.0014701687402628749, 'including': 0.0014043402892063284, 'example': 0.0013165690211309328, 'may': 0.0013165690211309328, 'donald': 0.0013165690211309328, 'several': 0.001272683387093235, 'organizational': 0.001272683387093235, 'within': 0.001272683387093235, 'needs': 0.0012287977530555372, 'class': 0.0012287977530555372, 'between': 0.0011849121190178394, 'student': 0.0011849121190178394, 'programs': 0.0011849121190178394, 'where': 0.0011629693019989907, 'organization': 0.0011410264849801418, 'committee': 0.001119083667961293, 'oc': 0.001097140850942444, 'needed': 0.001097140850942444, 'mark': 0.001097140850942444, 'used': 0.0010751980339235951, 'leaders': 0.0010532552169047462, 'internal': 0.0010532552169047462, 'x': 0.0010532552169047462, 'part': 0.0010313123998858973, 'quarter': 0.0010313123998858973, 'made': 0.0010093695828670484, 'external': 0.0010093695828670484, 'framework': 0.0009874267658481995, 'technical': 0.0009874267658481995, 'different': 0.0009654839488293508, 'years': 0.0009654839488293508, 'graduates': 0.0009654839488293508}

# %%
#get the frequency of the top words in the english language using datamuse API
import requests
import json

top_words_frequency = dict()
for word in top_words:
    word_frequency_request = requests.get("https://api.datamuse.com/words?sp=" + word[0] + "&md=f")
    word_frequency_json = word_frequency_request.json()
    try:
        word_frequency = word_frequency_json[0]['tags'][0][2:]
    #if try fails, set frequency to minimum decimal value
    except:
        word_frequency = 0.001
    #f is occurances per million, so divide by 1000000 to get frequency
    word_frequency = float(word_frequency) / 1000000
    top_words_frequency[word[0]] = word_frequency
print(top_words_frequency)
# Out:
# {'are': 0.001982889722, 'curriculum': 1.9310973e-05, 'industry': 9.4801556e-05, 'skills': 5.0081333e-05, 'college': 8.780276499999999e-05, 'was': 0.002824169367, 'students': 0.000137879575, 'change': 0.000236175639, 'faculty': 2.2926635e-05, 'were': 0.0009467195809999999, 'changes': 0.00015794770299999998, 'process': 0.00025717594000000004, 'program': 0.00014267237499999998, 'research': 0.00022340794299999998, 'through': 0.000528946114, 'knowledge': 0.000153343727, 'professors': 6.852528999999999e-06, 'video': 1.8873229e-05, 'department': 9.364976400000001e-05, 'et': 0.00027619985100000004, 'al': 0.000260171497, 'data': 0.000266210894, 'development': 0.000283987985, 'colleges': 1.3951497e-05, 'learning': 9.8584153e-05, 'gap': 2.1793311e-05, 'oceanfront': 8.4936e-08, 'has': 0.000412414222, 'members': 0.00015570981, 'gaming': 1.3876710000000001e-06, 'study': 0.000242114955, 'game': 5.386536799999999e-05, 'help': 0.000194370396, 'need': 0.000264497187, 'administrators': 9.892929e-06, 'should': 8.752447e-06, 'ideas': 8.1518434e-05, 'order': 0.00026218098199999997, 'participants': 2.5314992e-05, 'information': 0.000274478822, 'course': 0.000220505096, 'idea': 0.000118656309, 'education': 0.000185794009, 'more': 0.001291879626, 'including': 0.000126262129, 'example': 0.000295866105, 'may': 9.8668744e-05, 'donald': 1.0540046e-05, 'several': 0.000234353363, 'organizational': 2.5691588e-05, 'within': 0.000296202812, 'needs': 0.000114448074, 'class': 0.000160716521, 'between': 0.000636782057, 'student': 6.7350275e-05, 'programs': 7.7518212e-05, 'where': 0.000397281742, 'organization': 0.000101691687, 'committee': 8.6464758e-05, 'oc': 2.159161e-06, 'needed': 0.000106492217, 'mark': 4.9983117e-05, 'used': 0.000505450635, 'leaders': 5.9773388e-05, 'internal': 6.6761611e-05, 'x': 9.0317779e-05, 'part': 0.00038225642, 'quarter': 2.3360783999999998e-05, 'made': 0.000543336821, 'external': 5.6146425000000003e-05, 'framework': 3.4159962e-05, 'technical': 5.6536102e-05, 'different': 0.000355390509, 'years': 0.00044279047300000004, 'graduates': 6.826735e-06}

# %%
percent_gap = dict()
for word in top_words:
    gap = in_text_frequency[word[0]]/top_words_frequency[word[0]]
    #round to 2 decimal places
    gap = round(gap, 2)
    percent_gap[word[0]] = gap
percent_gap_sorted = dict(sorted(percent_gap.items(), key=value_getter, reverse=True))
print(percent_gap_sorted)
# Out:
# {'oceanfront': 23251.08, 'gaming': 1312.45, 'oc': 508.13, 'curriculum': 422.7, 'professors': 349.03, 'faculty': 201.95, 'should': 195.55, 'administrators': 173.01, 'colleges': 155.71, 'graduates': 141.43, 'video': 126.73, 'donald': 124.91, 'skills': 118.3, 'gap': 91.62, 'industry': 70.83, 'participants': 66.74, 'college': 65.73, 'organizational': 49.54, 'quarter': 44.15, 'students': 38.35, 'game': 33.0, 'framework': 28.91, 'department': 25.31, 'mark': 21.95, 'changes': 21.81, 'ideas': 20.73, 'learning': 20.7, 'program': 20.46, 'change': 20.35, 'knowledge': 18.17, 'external': 17.98, 'leaders': 17.62, 'student': 17.59, 'technical': 17.47, 'internal': 15.78, 'programs': 15.29, 'may': 13.34, 'idea': 13.13, 'research': 12.96, 'committee': 12.94, 'process': 12.37, 'members': 12.26, 'x': 11.66, 'organization': 11.22, 'including': 11.12, 'needs': 10.74, 'needed': 10.3, 'help': 9.14, 'al': 9.11, 'data': 8.82, 'et': 8.58, 'education': 7.91, 'development': 7.73, 'class': 7.65, 'study': 7.43, 'course': 7.26, 'need': 6.55, 'order': 6.44, 'information': 5.92, 'through': 5.48, 'several': 5.43, 'were': 4.75, 'has': 4.74, 'example': 4.45, 'are': 4.32, 'within': 4.3, 'where': 2.93, 'different': 2.72, 'part': 2.7, 'years': 2.18, 'used': 2.13, 'was': 1.9, 'between': 1.86, 'made': 1.86, 'more': 1.14}

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

#create a pie chart of the top 10 words from top_words
top_10_words = list(top_words)[:20]
top_10_words = dict(top_10_words)
plt.figure(figsize=(15,15))
plt.rcParams.update({'font.size': 18})
plt.pie(top_10_words.values(), labels=top_10_words.keys(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x243e4430cd0>,
#   <matplotlib.patches.Wedge at 0x243e4430310>,
#   <matplotlib.patches.Wedge at 0x243e443caf0>,
#   <matplotlib.patches.Wedge at 0x243e43b1a90>,
#   <matplotlib.patches.Wedge at 0x243e4435c70>,
#   <matplotlib.patches.Wedge at 0x243e4435190>,
#   <matplotlib.patches.Wedge at 0x243e4435640>,
#   <matplotlib.patches.Wedge at 0x243d79fdcd0>,
#   <matplotlib.patches.Wedge at 0x243e4516340>,
#   <matplotlib.patches.Wedge at 0x243e4516c40>,
#   <matplotlib.patches.Wedge at 0x243e44307f0>,
#   <matplotlib.patches.Wedge at 0x243d74302e0>,
#   <matplotlib.patches.Wedge at 0x243d7430460>,
#   <matplotlib.patches.Wedge at 0x243e4428bb0>,
#   <matplotlib.patches.Wedge at 0x243e4428be0>,
#   <matplotlib.patches.Wedge at 0x243e42cec70>,
#   <matplotlib.patches.Wedge at 0x243bbcec820>,
#   <matplotlib.patches.Wedge at 0x243bbcec1f0>,
#   <matplotlib.patches.Wedge at 0x243e4701970>,
#   <matplotlib.patches.Wedge at 0x243e440c7f0>],
#  [Text(1.0483393201360443, 0.33314361746354487, 'are'),
#   Text(0.6761024497164314, 0.8676897357278353, 'curriculum'),
#   Text(0.1393473080655846, 1.0911380882981196, 'industry'),
#   Text(-0.3537546750944432, 1.0415649906985283, 'skills'),
#   Text(-0.748129481841557, 0.806413218145315, 'college'),
#   Text(-1.0034594046318583, 0.4506320264427248, 'was'),
#   Text(-1.099178143558336, 0.04251362985737597, 'students'),
#   Text(-1.0426761673471765, -0.35046598985665195, 'change'),
#   Text(-0.8666217602533275, -0.6774708293760141, 'faculty'),
#   Text(-0.6019869940242222, -0.9206582748369132, 'were'),
#   Text(-0.3182228845874047, -1.052964479802083, 'changes'),
#   Text(-0.060718059422265054, -1.0983229567208337, 'process'),
#   Text(0.17970241377621285, -1.0852221166576927, 'program'),
#   Text(0.4010287568899132, -1.024292895683325, 'research'),
#   Text(0.6041645266048055, -0.9192307788539239, 'through'),
#   Text(0.7781242995108513, -0.7775104980067774, 'knowledge'),
#   Text(0.908606557112776, -0.6200275190438468, 'professors'),
#   Text(1.0013150243674076, -0.45537701081202814, 'video'),
#   Text(1.0642576138098299, -0.2781289834731492, 'department'),
#   Text(1.0960093495032333, -0.09361359837918784, 'et')],
#  [Text(0.5718214473469332, 0.18171470043466084, '9.8%'),
#   Text(0.36878315439078074, 0.473285310397001, '9.3%'),
#   Text(0.07600762258122795, 0.5951662299807925, '7.7%'),
#   Text(-0.1929570955060599, 0.5681263585628334, '6.8%'),
#   Text(-0.4080706264590311, 0.43986175535198996, '6.6%'),
#   Text(-0.547341493435559, 0.24579928715057714, '6.2%'),
#   Text(-0.5995517146681832, 0.023189252649477802, '6.1%'),
#   Text(-0.5687324549166417, -0.1911632671945374, '5.5%'),
#   Text(-0.47270277831999674, -0.3695295432960076, '5.3%'),
#   Text(-0.32835654219503024, -0.5021772408201345, '5.1%'),
#   Text(-0.17357611886585708, -0.574344261710227, '3.9%'),
#   Text(-0.03311894150305366, -0.5990852491204547, '3.6%'),
#   Text(0.09801949842338882, -0.5919393363587414, '3.3%'),
#   Text(0.21874295830358897, -0.5587052158272682, '3.3%'),
#   Text(0.32954428723898477, -0.5013986066475948, '3.3%'),
#   Text(0.42443143609682793, -0.424096635276424, '3.2%'),
#   Text(0.4956035766069687, -0.33819682856937094, '2.7%'),
#   Text(0.5461718314731314, -0.24838746044292442, '2.7%'),
#   Text(0.5805041529871798, -0.15170671825808135, '2.7%'),
#   Text(0.5978232815472181, -0.05106196275228427, '2.7%')])

# %%
#create a pie chart of the top 5 words from percent_gap_sorted using logarithmic scale to account for small numbers
top_5_pct_gap = list(percent_gap_sorted.items())[:20]
top_5_pct_gap = dict(top_5_pct_gap)
#convert to log scale
for word in top_5_pct_gap:
    top_5_pct_gap[word] = math.log(top_5_pct_gap[word])
plt.figure(figsize=(10,10))
plt.figure(figsize=(15,15))
plt.rcParams.update({'font.size': 18})
plt.pie(top_5_pct_gap.values(), labels=top_5_pct_gap.keys(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x243e48fa5e0>,
#   <matplotlib.patches.Wedge at 0x243e48fa520>,
#   <matplotlib.patches.Wedge at 0x243e49bc6d0>,
#   <matplotlib.patches.Wedge at 0x243e49bceb0>,
#   <matplotlib.patches.Wedge at 0x243d6ea5ca0>,
#   <matplotlib.patches.Wedge at 0x243e481f370>,
#   <matplotlib.patches.Wedge at 0x243e481fe80>,
#   <matplotlib.patches.Wedge at 0x243d729b520>,
#   <matplotlib.patches.Wedge at 0x243e47ff070>,
#   <matplotlib.patches.Wedge at 0x243e47ff370>,
#   <matplotlib.patches.Wedge at 0x243e48fa910>,
#   <matplotlib.patches.Wedge at 0x243e4900b50>,
#   <matplotlib.patches.Wedge at 0x243e44fec70>,
#   <matplotlib.patches.Wedge at 0x243e44fe670>,
#   <matplotlib.patches.Wedge at 0x243e49280d0>,
#   <matplotlib.patches.Wedge at 0x243e49fd610>,
#   <matplotlib.patches.Wedge at 0x243e49fd070>,
#   <matplotlib.patches.Wedge at 0x243e4803ee0>,
#   <matplotlib.patches.Wedge at 0x243e4a02280>,
#   <matplotlib.patches.Wedge at 0x243e4a02550>],
#  [Text(1.049702369715529, 0.3288235621326476, 'oceanfront'),
#   Text(0.7472812960059736, 0.8071992719518722, 'gaming'),
#   Text(0.36886897580412653, 1.036308679250162, 'oc'),
#   Text(-0.03160982495878105, 1.0995457330034415, 'curriculum'),
#   Text(-0.41627487972595445, 1.0181921353600911, 'professors'),
#   Text(-0.7295809022835327, 0.8232324744706968, 'faculty'),
#   Text(-0.95126596068895, 0.5523523078928244, 'should'),
#   Text(-1.0755641398567226, 0.23056838693599932, 'administrators'),
#   Text(-1.0948457388001678, -0.10636168591704044, 'colleges'),
#   Text(-1.0136907486096054, -0.42711949871587235, 'graduates'),
#   Text(-0.8452183833368937, -0.7039928156376086, 'video'),
#   Text(-0.6068166445442699, -0.917482185060851, 'donald'),
#   Text(-0.31924310880940265, -1.0526556120012414, 'skills'),
#   Text(-0.01532355952107219, -1.099893262332125, 'gap'),
#   Text(0.2733253271399472, -1.0655014150829838, 'industry'),
#   Text(0.533709178721891, -0.9618495269781052, 'participants'),
#   Text(0.7576515154970486, -0.7974736240560096, 'college'),
#   Text(0.9279964966841903, -0.5906119725690208, 'organizational'),
#   Text(1.0390030293013401, -0.361210056757337, 'quarter'),
#   Text(1.0933385305153693, -0.12087538082874066, 'students')],
#  [Text(0.5725649289357431, 0.17935830661780774, '9.7%'),
#   Text(0.4076079796396219, 0.44029051197374847, '6.9%'),
#   Text(0.20120125952952353, 0.5652592795909973, '6.0%'),
#   Text(-0.01724172270478966, 0.5997522180018771, '5.8%'),
#   Text(-0.22705902530506603, 0.5553775283782315, '5.6%'),
#   Text(-0.39795321942738143, 0.4490358951658346, '5.1%'),
#   Text(-0.5188723421939726, 0.3012830770324496, '5.1%'),
#   Text(-0.5866713490127576, 0.12576457469236327, '5.0%'),
#   Text(-0.5971885848000914, -0.05801546504565842, '4.9%'),
#   Text(-0.5529222265143301, -0.23297427202683943, '4.8%'),
#   Text(-0.461028209092851, -0.3839960812568774, '4.7%'),
#   Text(-0.33099089702414713, -0.5004448282150096, '4.6%'),
#   Text(-0.17413260480512868, -0.5741757883643134, '4.6%'),
#   Text(-0.008358305193312102, -0.5999417794538863, '4.3%'),
#   Text(0.14908654207633482, -0.5811825900452638, '4.1%'),
#   Text(0.2911140974846678, -0.5246451965335118, '4.0%'),
#   Text(0.4132644629983901, -0.4349856131214597, '4.0%'),
#   Text(0.5061799072822856, -0.3221519850376477, '3.8%'),
#   Text(0.5667289250734582, -0.19702366732218377, '3.6%'),
#   Text(0.5963664711902014, -0.06593202590658581, '3.5%')])

# %%
#create a grouped bar chart for the top 10 and bottom 10 words showing their frequency in the text and in the english language
top_5_words = list(percent_gap_sorted)[:10]
bottom_5_words = list(percent_gap_sorted)[-10:]
words_frequency = dict()
for word in top_5_words:
    words_frequency[word] = [in_text_frequency[word], top_words_frequency[word]]
for word in bottom_5_words:
    words_frequency[word] = [in_text_frequency[word], top_words_frequency[word]]

print(words_text_frequency)

#create the clustered bar chart, each word will have 2 bars
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
ax.set_title('Frequency of Top and Bottom 10 Words in Text and English Language')
ax.set_xlabel('Words')
ax.set_ylabel('Frequency')
ax.set_xticks(np.arange(len(words_frequency)))
ax.set_xticklabels(words_frequency.keys())
#make x labels smaller
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
    tick.label.set_fontweight('bold')

ax.bar(np.arange(len(words_frequency)), [x[0] for x in words_frequency.values()], width=0.4, color='g', align='center')
ax.bar(np.arange(len(words_frequency)) + 0.4, [x[1] for x in words_frequency.values()], width=0.4, color='r', align='center')
ax.legend(['Text', 'English Language'])
plt.show()
# Out:
# {'shall': [0.011939632055485315, 4.437348e-06], 'unto': [0.010916755040975749, 1.3648508e-05], 'lord': [0.009500743800248986, 9.0552461e-05], 'thou': [0.0066420270194844115, 2.4309764e-05], 'thy': [0.005581535310491102, 4.374721e-06], 'thus': [0.0008954724041613986, 0.000285333682], 'bring': [0.0008796985000230542, 8.2760129e-05], 'offering': [0.0008784851227816431, 1.9015788e-05], 'place': [0.0008699914820917652, 0.000302443694], 'set': [0.0008530042007120098, 0.000252662112]}
# C:\Users\jsher\AppData\Local\Temp\ipykernel_19740\3119211296.py:22: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)
# C:\Users\jsher\AppData\Local\Temp\ipykernel_19740\3119211296.py:23: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontweight('bold')

# %%
#generate a word cloud of the top 20 words by frequency
try: 
    from wordcloud import WordCloud
except:
    # !pip install wordcloud
    from wordcloud import WordCloud

top_20_words = list(percent_gap_sorted.items())[:20]
top_20_words = dict(top_20_words)
#convert to log scale
for word in top_20_words:
    top_20_words[word] = math.log(top_20_words[word])

wordcloud = WordCloud(width=480, height=480, margin=0, colormap='Greens').generate_from_frequencies(top_20_words)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
#generate a word cloud of the bottom 20 words by frequency, this one should be warmer colors, small values should be larger
bottom_20_words = list(percent_gap_sorted.items())[-20:]
bottom_20_words = dict(bottom_20_words)

#convert to log scale
for word in bottom_20_words:
    bottom_20_words[word] = math.log(bottom_20_words[word])

wordcloud = WordCloud(width=480, height=480, margin=0, colormap='Reds').generate_from_frequencies(bottom_20_words)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
