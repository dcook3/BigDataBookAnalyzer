# %%
import re
#with open(r"mobydick.txt") as f:
#with open(r"hobbit.txt") as f:
#with open(r"originalTrilogy.txt") as f:
#with open(r"bible.txt") as f:
with open(r"BigData.txt") as f:
    #Read each line of file and add into list
    lines = f.readlines()

words = []
num_words = 75

#Track line index as well as line
i = 0
for line in lines:
    #Split all words on space (default)
    split_line = line.split()
    
    #Find non-desired characters make new word without them and replace old word with new in same postion
    for i in range(len(split_line)):
        #Remove any occurance of non-alphabetical characters by removing matches using this regular expression
        newword = re.sub(r"[^\w]|\d", "", split_line[i])
        split_line[i] = newword
    
    #Right now, split line is still not in its most simple form. Each line is represented by a list.
    #We would rather have one list with all words, not a 2 dimensional list of lines with words.
    for word in split_line:
        words.append(word.lower())    
    i += 1
    
print(words)
# Out:
# ['a', 'long', 'time', 'ago,', 'in', 'a', 'galaxy', 'far,', 'far,', 'away.', 'a', 'vast', 'sea', 'of', 'stars', 'serves', 'as', 'the', 'backdrop', 'for', 'the', 'main', 'title.', 'war', 'drums', 'echo', 'through', 'the', 'heavens', 'as', 'a', 'rollup', 'slowly', 'crawls', 'into', 'infinity.', 'it', 'is', 'a', 'period', 'of', 'civil', 'war.', 'rebel', 'spaceships,', 'striking', 'from', 'a', 'hidden', 'base,', 'have', 'won', 'their', 'first', 'victory', 'against', 'the', 'evil', 'galactic', 'empire.', 'during', 'the', 'battle,', 'rebel', 'spies', 'managed', 'to', 'steal', 'secret', 'plans', 'to', 'the', "empire's", 'ultimate', 'weapon,', 'the', 'death', 'star,', 'an', 'armored', 'space', 'station', 'with', 'enough', 'power', 'to', 'destroy', 'an', 'entire', 'planet.', 'pursued', 'by', 'the', "empire's", 'sinister', 'agents,', 'princess', 'leia', 'races', 'home', 'aboard', 'her', 'starship,', 'custodian', 'of', 'the', 'stolen', 'plans', 'that', 'can', 'save', 'her', 'people', 'and', 'restore', 'freedom', 'to', 'the', 'galaxy.', 'the', 'awesome', 'yellow', 'planet', 'of', 'tatooine', 'emerges', 'from', 'a', 'total', 'eclipse,', 'her', 'two', 'moons', 'glowing', 'against', 'the', 'darkness.', 'a', 'tiny', 'silver', 'spacecraft,', 'a', 'rebel', 'blockade', 'runner', 'firing', 'lasers', 'from', 'the', 'back', 'of', 'the', 'ship,', 'races', 'through', 'space.', 'it', 'is', 'pursed', 'by', 'a', 'giant', 'imperial', 'stardestroyer.', 'hundreds', 'of', 'deadly', 'laserbolts', 'streak', 'from', 'the', 'imperial', 'stardestroyer,', 'causing', 'the', 'main', 'solar', 'fin', 'of', 'the', 'rebel', 'craft', 'to', 'disintegrate.', 'int.', 'rebel', 'blockade', 'runner', '', 'main', 'passageway', 'an', 'explosion', 'rocks', 'the', 'ship', 'as', 'two', 'robots,', 'artoo-detoo', 'r', 'd', 'and', 'see-threepio', 'c-po)', 'struggle', 'to', 'make', 'their', 'way', 'through', 'the', 'shaking,', 'bouncing', 'passageway.', 'both', 'robots', 'are', 'old', 'and', 'battered.', 'artoo', 'is', 'a', 'short,', 'claw-armed', 'tripod.', 'his', 'face', 'is', 'a', 'mass', 'of', 'computer', 'lights', 'surrounding', 'a', 'radar', 'eye.', 'threepio,', 'on', 'the', 'other', 'hand,', 'is', 'a', 'tall,', 'slender', 'robot', 'of', 'human', 'proportions.', 'he', 'has', 'a', 'gleaming', 'bronze-like', 'metallic', 'surface', 'of', 'an', 'art', 'deco', 'design.', 'another', 'blast', 'shakes', 'them', 'as', 'they', 'struggle', 'along', 'their', 'way.', 'threepio', 'did', 'you', 'hear', 'that?', "they've", 'shut', 'down', 'the', 'main', 'reactor.', "we'll", 'be', 'destroyed', 'for', 'sure.', 'this', 'is', 'madness!', 'rebel', 'troopers', 'rush', 'past', 'the', 'robots', 'and', 'take', 'up', 'positions', 'in', 'the', 'main', 'passageway.', 'they', 'aim', 'their', 'weapons', 'toward', 'the', 'door.', 'threepio', "we're", 'doomed!', 'the', 'little', 'r', 'unit', 'makes', 'a', 'series', 'of', 'electronic', 'sounds', 'that', 'only', 'another', 'robot', 'could', 'understand.', 'threepio', "there'll", 'be', 'no', 'escape', 'for', 'the', 'princess', 'this', 'time.', 'artoo', 'continues', 'making', 'beeping', 'sounds.', 'tension', 'mounts', 'as', 'loud', 'metallic', 'latches', 'clank', 'and', 'the', 'scream', 'of', 'heavy', 'equipment', 'are', 'heard', 'moving', 'around', 'the', 'outside', 'hull', 'of', 'the', 'ship.', 'threepio', "what's", 'that?', 'ext.', 'spacecraft', 'in', 'space', 'the', 'imperial', 'craft', 'has', 'easily', 'overtaken', 'the', 'rebel', 'blockade', 'runner.', 'the', 'smaller', 'rebel', 'ship', 'is', 'being', 'drawn', 'into', 'the', 'underside', 'dock', 'of', 'the', 'giant', 'imperial', 'starship.', 'int.', 'rebel', 'blockade', 'runner', 'the', 'nervous', 'rebel', 'troopers', 'aim', 'their', 'weapons.', 'suddenly', 'a', 'tremendous', 'blast', 'opens', 'up', 'a', 'hole', 'in', 'the', 'main', 'passageway', 'and', 'a', 'score', 'of', 'fearsome', 'armored', 'spacesuited', 'stormtroopers', 'make', 'their', 'way', 'into', 'the', 'smoke-filled', 'corridor.', 'in', 'a', 'few ...

# %%
#read in words from topWords.txt as top_100
with open(r"topWords.txt") as f:
    top_100 = f.read().split()
print (top_100)
# Out:
# ['the', 'be', 'to', 'of', 'and', 'a', 'in', 'that', 'have', 'i', 'it', 'for', 'not', 'on', 'with', 'he', 'as', 'you', 'do', 'at', 'this', 'but', 'his', 'by', 'from', 'they', 'we', 'say', 'her', 'she', 'or', 'an', 'will', 'my', 'one', 'all', 'would', 'there', 'their', 'what', 'so', 'up', 'out', 'if', 'about', 'who', 'get', 'which', 'go', 'me', 'when', 'make', 'can', 'like', 'time', 'no', 'just', 'him', 'know', 'take', 'people', 'into', 'year', 'your', 'good', 'some', 'could', 'them', 'see', 'other', 'than', 'then', 'now', 'look', 'only', 'come', 'its', 'is', 'over', 'think', 'also', 'back', 'after', 'use', 'two', 'how', 'our', 'work', 'first', 'well', 'way', 'even', 'new', 'want', 'because', 'any', 'these', 'give', 'day', 'most', 'us']

# %%
def value_getter(item):
    return item[1]

#Track words using a word:wordcount dictionary.
words_dict = dict()

for word in words:
    #Determine whether exists to know whether to add a new k/v pair or increment the matching key word
    if word not in words_dict:
        words_dict[word] = 1
    else:
        words_dict[word] = words_dict[word] + 1

#remove '' from words_dict
words_dict.pop('')
for word in top_100:
    if word in words_dict:
        words_dict.pop(word)
#Sort using sorted(), in this case we pull out word and use value_getter to maintain k/v pairs during sort.
words_sorted = dict(sorted(words_dict.items(), key=value_getter, reverse=True))
        
print(words_sorted)
# Out:
# {'luke': 1095, 'han': 763, 'leia': 479, 'int.': 472, 'threepio': 463, 'star': 353, 'are': 341, 'vader': 321, 'death': 295, 'cockpit': 289, 'ext.': 283, 'artoo': 213, 'rebel': 211, 'imperial': 210, 'falcon': 209, 'ben': 199, "luke's": 196, 'lando': 195, 'toward': 191, 'looks': 182, 'millennium': 182, 'chewie': 182, "don't": 174, 'down': 172, 'around': 172, "i'm": 171, 'red': 162, 'off': 159, 'through': 155, 'him.': 151, 'has': 148, 'space': 147, 'moves': 143, "it's": 125, 'little': 124, 'control': 121, 'turns': 119, 'ship': 118, 'tie': 118, 'it.': 113, 'room': 111, 'x-wing': 111, 'going': 109, 'main': 106, 'laser': 106, 'fighter': 105, 'luke,': 103, 'side': 102, 'away': 100, "vader's": 98, 'leader': 98, 'huge': 97, 'small': 96, 'begins': 94, 'where': 94, 'before': 94, 'head': 94, 'was': 92, "you're": 91, 'more': 89, 'emperor': 89, 'behind': 84, 'you.': 81, 'fighters': 81, 'surface': 80, 'luke.': 80, 'oh,': 80, 'jabba': 80, "we're": 79, 'gold': 79, 'giant': 78, 'got': 78, 'across': 78, 'yoda': 76, 'another': 75, 'them.': 75, 'several': 73, 'dark': 73, 'been': 72, 'door': 72, 'well,': 70, 'ext': 70, 'darth': 69, 'officer': 69, 'hoth': 69, 'stormtroopers': 68, 'move': 68, 'very': 67, 'large': 66, 'cloud': 66, 'ship.': 65, 'must': 65, 'me.': 65, 'voice': 65, 'int': 65, 'old': 62, 'comlink)': 62, 'long': 61, 'starts': 61, 'creature': 61, 'stands': 60, 'troops': 60, 'three': 60, 'princess': 59, 'makes': 59, 'hold': 59, 'han,': 59, 'power': 58, 'here.': 58, 'chewbacca': 58, 'takes': 57, 'jedi': 57, 'against': 56, 'face': 56, 'suddenly': 56, 'biggs': 56, "he's": 56, "can't": 56, 'fire': 56, 'destroyer': 56, 'young': 55, 'something': 53, "that's": 53, 'city': 53, "i'll": 53, 'races': 52, "i've": 52, 'yes,': 52, 'speeder': 52, 'away.': 51, 'beeps': 51, 'droid': 51, 'computer': 50, 'here': 50, 'group': 50, 'asteroid': 50, 'bridge': 50, 'deck': 50, 'right': 49, 'watches': 49, "there's": 49, 'chewie,': 49, 'base': 49, 'wedge': 49, 'tatooine': 48, 'artoo,': 48, 'stand': 48, 'ice': 48, 'had': 47, 'standing': 47, 'lets': 46, 'coming': 46, 'lord': 45, 'hand': 45, 'front': 45, 'too': 45, 'followed': 45, 'leia,': 45, 'piett': 45, 'past': 44, 'few': 44, 'eyes': 44, 'find': 44, 'sits': 44, 'looking': 44, 'still': 44, 'guards': 44, "le
    word_frequency_json = word_frequency_request.json()
    try:
        word_frequency = word_frequency_json[0]['tags'][0][2:]
    #if try fails, set frequency to minimum decimal value
    except:
        word_frequency = 0.001
    #f is occurances per million, so divide by 1000000 to get frequency
    word_frequency = float(word_frequency) / 1000000
    top_words_frequency[word[0]] = word_frequency
print(top_words_frequency)
# Out:
# {'luke': 1.0067042e-05, 'han': 5.209024e-06, 'leia': 7.9041e-08, 'int.': 1e-09, 'threepio': 1.5939999999999999e-09, 'star': 2.8722372e-05, 'are': 0.001982889722, 'vader': 1.24211e-07, 'death': 0.000163536308, 'cockpit': 1.7073370000000001e-06, 'ext.': 1e-09, 'artoo': 3.3500000000000002e-09, 'rebel': 6.3450470000000005e-06, 'imperial': 1.9695921e-05, 'falcon': 1.473495e-06, 'ben': 1.6168405e-05, "luke's": 8.4674e-08, 'lando': 1.17492e-07, 'toward': 0.000133279693, 'looks': 3.9057723e-05, 'millennium': 3.929243e-06, 'chewie': 1.3537e-08, "don't": 2.3268e-07, 'down': 0.000188994664, 'around': 0.000220968074, "i'm": 1e-09, 'red': 9.9240438e-05, 'off': 9.8391485e-05, 'through': 0.000528946114, 'him.': 1e-09, 'has': 0.000412414222, 'space': 0.00011370227099999999, 'moves': 2.345232e-05, "it's": 1e-09, 'little': 0.000343154023, 'control': 0.000246187606, 'turns': 2.6510158e-05, 'ship': 3.9647628e-05, 'tie': 1.2897448000000001e-05, 'it.': 1e-09, 'room': 0.00015856048, 'x-wing': 9.0317779e-05, 'going': 0.000198590107, 'main': 0.00012273204, 'laser': 1.4433146e-05, 'fighter': 4.955572e-06, 'luke,': 1.0067042e-05, 'side': 0.000188963448, 'away': 0.00019175632300000002, "vader's": 8.085999999999999e-09, 'leader': 4.3757188e-05, 'huge': 2.9036738e-05, 'small': 0.000293185303, 'begins': 3.6954862e-05, 'where': 0.000397281742, 'before': 0.000336211949, 'head': 0.000188298221, 'was': 0.002824169367, "you're": 7.0162e-08, 'more': 0.001291879626, 'emperor': 2.058273e-05, 'behind': 0.000106822256, 'you.': 1e-09, 'fighters': 4.4248180000000005e-06, 'surface': 0.000123607564, 'luke.': 1.0067042e-05, 'oh,': 6.1084012e-05, 'jabba': 2.5207e-08, "we're": 0.0009467195809999999, 'gold': 5.2502372000000004e-05, 'giant': 1.3959948000000001e-05, 'got': 0.00015713220200000002, 'across': 0.000113890987, 'yoda': 6.293999999999999e-08, 'another': 0.000112735469}

# %%
percent_gap = dict()
for word in top_words:
    gap = in_text_frequency[word[0]]/top_words_frequency[word[0]]
    #round to 2 decimal places
    gap = round(gap, 2)
    percent_gap[word[0]] = gap
percent_gap_sorted = dict(sorted(percent_gap.items(), key=value_getter, reverse=True))
print(percent_gap_sorted)
# Out:
# {'int.': 5599715.27, 'threepio': 3446010.69, 'ext.': 3357456.4, "i'm": 2028710.4, 'him.': 1791434.33, "it's": 1482975.44, 'it.': 1340609.8, 'you.': 960968.09, 'artoo': 754325.42, 'chewie': 159504.49, "vader's": 143785.89, 'leia': 71896.38, 'jabba': 37652.41, 'vader': 30659.77, "luke's": 27461.86, 'lando': 19690.21, "you're": 15387.33, 'yoda': 14325.53, "don't": 8871.85, 'cockpit': 2008.18, 'han': 1737.77, 'falcon': 1682.76, 'luke': 1290.44, 'millennium': 549.52, 'rebel': 394.52, 'fighter': 251.37, 'fighters': 217.18, 'ben': 146.02, 'star': 145.81, 'imperial': 126.49, 'luke,': 121.38, 'tie': 108.54, 'luke.': 94.28, 'laser': 87.13, 'moves': 72.34, 'giant': 66.29, 'looks': 55.28, 'turns': 53.25, 'emperor': 51.3, 'huge': 39.63, 'ship': 35.31, 'begins': 30.18, 'leader': 26.57, 'death': 21.4, 'red': 19.37, 'off': 19.17, 'gold': 17.85, 'toward': 17.0, 'oh,': 15.54, 'space': 15.34, 'x-wing': 14.58, 'down': 10.8, 'main': 10.25, 'behind': 9.33, 'around': 9.23, 'room': 8.31, 'across': 8.13, 'another': 7.89, 'surface': 7.68, 'going': 6.51, 'side': 6.4, 'away': 6.19, 'head': 5.92, 'got': 5.89, 'control': 5.83, 'little': 4.29, 'has': 4.26, 'small': 3.88, 'through': 3.48, 'before': 3.32, 'where': 2.81, 'are': 2.04, "we're": 0.99, 'more': 0.82, 'was': 0.39}

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

#create a pie chart of the top 10 words from top_words
top_10_words = list(top_words)[:20]
top_10_words = dict(top_10_words)
plt.figure(figsize=(15,15))
plt.rcParams.update({'font.size': 18})
plt.pie(top_10_words.values(), labels=top_10_words.keys(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x243b9c76460>,
#   <matplotlib.patches.Wedge at 0x243b9c763a0>,
#   <matplotlib.patches.Wedge at 0x243b9c7a190>,
#   <matplotlib.patches.Wedge at 0x243b9c7a820>,
#   <matplotlib.patches.Wedge at 0x243b9c7aeb0>,
#   <matplotlib.patches.Wedge at 0x243b8243580>,
#   <matplotlib.patches.Wedge at 0x243b8243c10>,
#   <matplotlib.patches.Wedge at 0x243b827f2e0>,
#   <matplotlib.patches.Wedge at 0x243b827f970>,
#   <matplotlib.patches.Wedge at 0x243d88c0040>,
#   <matplotlib.patches.Wedge at 0x243b9c76430>,
#   <matplotlib.patches.Wedge at 0x243d88c0d30>,
#   <matplotlib.patches.Wedge at 0x243d88c3400>,
#   <matplotlib.patches.Wedge at 0x243d88c3a90>,
#   <matplotlib.patches.Wedge at 0x243d88e0160>,
#   <matplotlib.patches.Wedge at 0x243d88e07f0>,
#   <matplotlib.patches.Wedge at 0x243d88e0e80>,
#   <matplotlib.patches.Wedge at 0x243d88e1550>,
#   <matplotlib.patches.Wedge at 0x243d88e1c10>,
#   <matplotlib.patches.Wedge at 0x243bb8692e0>],
#  [Text(0.9683524045878795, 0.5218176123214622, 'luke'),
#   Text(0.25920319614167503, 1.069024650375257, 'han'),
#   Text(-0.3488781954788139, 1.043208514497196, 'leia'),
#   Text(-0.7514078055201833, 0.8033593901880668, 'int.'),
#   Text(-1.0145490423785997, 0.4250767467277722, 'threepio'),
#   Text(-1.0995552712745966, 0.03127627554950271, 'star'),
#   Text(-1.0556835630475334, -0.3090828605912408, 'are'),
#   Text(-0.9179133226856374, -0.6061642780931692, 'vader'),
#   Text(-0.7162787897429921, -0.8348321360395242, 'death'),
#   Text(-0.47401029960920327, -0.9926299591813625, 'cockpit'),
#   Text(-0.20485123190967924, -1.0807571294167284, 'ext.'),
#   Text(0.04020883228709605, -1.0992648679031403, 'artoo'),
#   Text(0.24857485550793978, -1.0715458651915963, 'rebel'),
#   Text(0.446502933314074, -1.005303501705792, 'imperial'),
#   Text(0.6275402625267527, -0.9034341253837241, 'falcon'),
#   Text(0.782368200972919, -0.7732399356644731, 'ben'),
#   Text(0.9071008899073928, -0.6222282342751864, "luke's"),
#   Text(1.0022573469915326, -0.4532992503870869, 'lando'),
#   Text(1.0656633837686853, -0.27269314713552323, 'toward'),
#   Text(1.0962902673873516, -0.09026433200201193, 'looks')],
#  [Text(0.5281922206842978, 0.28462778853897935, '15.7%'),
#   Text(0.14138356153182274, 0.5831043547501401, '11.0%'),
#   Text(-0.19029719753389848, 0.5690228260893796, '6.9%'),
#   Text(-0.409858803011009, 0.43819603101167276, '6.8%'),
#   Text(-0.5533903867519634, 0.2318600436696939, '6.7%'),
#   Text(-0.5997574206952344, 0.017059786663365117, '5.1%'),
#   Text(-0.5758273980259273, -0.16859065123158587, '4.9%'),
#   Text(-0.5006799941921658, -0.3306350607780923, '4.6%'),
#   Text(-0.39069752167799565, -0.4553629832942859, '4.2%'),
#   Text(-0.25855107251411086, -0.5414345231898341, '4.2%'),
#   Text(-0.11173703558709776, -0.5895038887727608, '4.1%'),
#   Text(0.021932090338416022, -0.5995990188562582, '3.1%'),
#   Text(0.1355862848225126, -0.5844795628317798, '3.0%'),
#   Text(0.2435470545349494, -0.5483473645667957, '3.0%'),
#   Text(0.34229468865095597, -0.492782250209304, '3.0%'),
#   Text(0.426746291439774, -0.4217672376351671, '2.9%'),
#   Text(0.49478230358585057, -0.33939721869555617, '2.8%'),
#   Text(0.546685825631745, -0.24725413657477466, '2.8%'),
#   Text(0.581270936601101, -0.14874171661937627, '2.7%'),
#   Text(0.5979765094840099, -0.0492350901829156, '2.6%')])

# %%
#create a pie chart of the top 5 words from percent_gap_sorted using logarithmic scale to account for small numbers
top_5_pct_gap = list(percent_gap_sorted.items())[:20]
top_5_pct_gap = dict(top_5_pct_gap)
#convert to log scale
for word in top_5_pct_gap:
    top_5_pct_gap[word] = math.log(top_5_pct_gap[word])
plt.figure(figsize=(10,10))
plt.figure(figsize=(15,15))
plt.rcParams.update({'font.size': 18})
plt.pie(top_5_pct_gap.values(), labels=top_5_pct_gap.keys(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x243b9866370>,
#   <matplotlib.patches.Wedge at 0x243b98662b0>,
#   <matplotlib.patches.Wedge at 0x243b9866f40>,
#   <matplotlib.patches.Wedge at 0x243b986b610>,
#   <matplotlib.patches.Wedge at 0x243b986bca0>,
#   <matplotlib.patches.Wedge at 0x243b9d33370>,
#   <matplotlib.patches.Wedge at 0x243b9d339a0>,
#   <matplotlib.patches.Wedge at 0x243b9d22070>,
#   <matplotlib.patches.Wedge at 0x243b9d22730>,
#   <matplotlib.patches.Wedge at 0x243b9d22dc0>,
#   <matplotlib.patches.Wedge at 0x243b9866340>,
#   <matplotlib.patches.Wedge at 0x243b9d0caf0>,
#   <matplotlib.patches.Wedge at 0x243b9d3e1c0>,
#   <matplotlib.patches.Wedge at 0x243b9d3e850>,
#   <matplotlib.patches.Wedge at 0x243b9d3eee0>,
#   <matplotlib.patches.Wedge at 0x243bb2635b0>,
#   <matplotlib.patches.Wedge at 0x243bb263c40>,
#   <matplotlib.patches.Wedge at 0x243bb258310>,
#   <matplotlib.patches.Wedge at 0x243bb2589a0>,
#   <matplotlib.patches.Wedge at 0x243bb26a070>],
#  [Text(1.0777131461480711, 0.22030518518552064, 'int.'),
#   Text(0.9087236373665066, 0.6198559113950483, 'threepio'),
#   Text(0.6045089362130098, 0.9190043231882075, 'ext.'),
#   Text(0.21676972278906104, 1.0784298249223052, "i'm"),
#   Text(-0.19363590048368212, 1.0828227639110075, 'him.'),
#   Text(-0.5732714120443351, 0.9388076949688337, "it's"),
#   Text(-0.8722832816049133, 0.6701655591214485, 'it.'),
#   Text(-1.0530417236774374, 0.3179671810021462, 'you.'),
#   Text(-1.0979440630343655, -0.06722227642373825, 'artoo'),
#   Text(-1.0164609520608525, -0.4204844027256488, 'chewie'),
#   Text(-0.8400355115330587, -0.7101692329039555, "vader's"),
#   Text(-0.5933515987555709, -0.9262472025621499, 'leia'),
#   Text(-0.31231801264911024, -1.0547309889137184, 'jabba'),
#   Text(-0.018802830490705087, -1.0998392853346974, 'vader'),
#   Text(0.27171951393788074, -1.0659120534759714, "luke's"),
#   Text(0.5375233676565431, -0.9597232044830264, 'lando'),
#   Text(0.7609829200799199, -0.7942952822135094, "you're"),
#   Text(0.9334329473765903, -0.5819819007081333, 'yoda'),
#   Text(1.0457562769510915, -0.341165369311412, "don't"),
#   Text(1.0946474570804894, -0.10838332301243775, 'cockpit')],
#  [Text(0.5878435342625842, 0.12016646464664761, '6.4%'),
#   Text(0.495667438563549, 0.338103224397299, '6.2%'),
#   Text(0.3297321470252781, 0.5012750853753859, '6.2%'),
#   Text(0.11823803061221509, 0.588234449957621, '6.0%'),
#   Text(-0.10561958208200843, 0.5906305984969131, '5.9%'),
#   Text(-0.31269349747872816, 0.5120769245284547, '5.9%'),
#   Text(-0.4757908808754072, 0.365544850429881, '5.8%'),
#   Text(-0.5743863947331477, 0.17343664418298885, '5.7%'),
#   Text(-0.5988785798369266, -0.03666669623112995, '5.6%'),
#   Text(-0.5544332465786467, -0.22935512875944478, '4.9%'),
#   Text(-0.45820118810894106, -0.38736503612943024, '4.9%'),
#   Text(-0.3236463265939477, -0.5052257468520817, '4.6%'),
#   Text(-0.17035527962678737, -0.5753078121347555, '4.4%'),
#   Text(-0.01025608935856641, -0.5999123374552895, '4.3%'),
#   Text(0.14821064396611675, -0.5814065746232571, '4.2%'),
#   Text(0.2931945641762962, -0.5234853842634689, '4.1%'),
#   Text(0.4150815927708653, -0.43325197211645966, '4.0%'),
#   Text(0.5091452440235947, -0.3174446731135272, '4.0%'),
#   Text(0.5704125147005953, -0.18609020144258837, '3.8%'),
#   Text(0.5970804311348122, -0.0591181761886024, '3.1%')])

# %%
#create a grouped bar chart for the top 10 and bottom 10 words showing their frequency in the text and in the english language
top_5_words = list(percent_gap_sorted)[:10]
bottom_5_words = list(percent_gap_sorted)[-10:]
words_frequency = dict()
for word in top_5_words:
    words_frequency[word] = [in_text_frequency[word], top_words_frequency[word]]
for word in bottom_5_words:
    words_frequency[word] = [in_text_frequency[word], top_words_frequency[word]]

print(words_text_frequency)

#create the clustered bar chart, each word will have 2 bars
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
ax.set_title('Frequency of Top and Bottom 10 Words in Text and English Language')
ax.set_xlabel('Words')
ax.set_ylabel('Frequency')
ax.set_xticks(np.arange(len(words_frequency)))
ax.set_xticklabels(words_frequency.keys())
#make x labels smaller
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
    tick.label.set_fontweight('bold')

text_container = ax.bar(np.arange(len(words_frequency)), [x[0] for x in words_frequency.values()], width=0.4, color='g', align='center')
eng_container = ax.bar(np.arange(len(words_frequency)) + 0.4, [x[1] for x in words_frequency.values()], width=0.4, color='r', align='center')
    
ax.legend(['Text', 'English Language'])
plt.show()
# Out:
# {'shall': [0.011939632055485315, 4.437348e-06], 'unto': [0.010916755040975749, 1.3648508e-05], 'lord': [0.009500743800248986, 9.0552461e-05], 'thou': [0.0066420270194844115, 2.4309764e-05], 'thy': [0.005581535310491102, 4.374721e-06], 'thus': [0.0008954724041613986, 0.000285333682], 'bring': [0.0008796985000230542, 8.2760129e-05], 'offering': [0.0008784851227816431, 1.9015788e-05], 'place': [0.0008699914820917652, 0.000302443694], 'set': [0.0008530042007120098, 0.000252662112]}
# C:\Users\jsher\AppData\Local\Temp\ipykernel_19740\1863901433.py:22: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)
# C:\Users\jsher\AppData\Local\Temp\ipykernel_19740\1863901433.py:23: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontweight('bold')

# %%
#generate a word cloud of the top 20 words by frequency
try: 
    from wordcloud import WordCloud
except:
    # !pip install wordcloud
    from wordcloud import WordCloud

top_20_words = list(percent_gap_sorted.items())[:20]
top_20_words = dict(top_20_words)
#convert to log scale
for word in top_20_words:
    top_20_words[word] = math.log(top_20_words[word])

wordcloud = WordCloud(width=480, height=480, margin=0, colormap='Greens').generate_from_frequencies(top_20_words)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
#generate a word cloud of the bottom 20 words by frequency, this one should be warmer colors, small values should be larger
bottom_20_words = list(percent_gap_sorted.items())[-20:]
bottom_20_words = dict(bottom_20_words)

#convert to log scale
for word in bottom_20_words:
    bottom_20_words[word] = math.log(bottom_20_words[word])

wordcloud = WordCloud(width=480, height=480, margin=0, colormap='Reds').generate_from_frequencies(bottom_20_words)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
